# %% [markdown]
# #Nama : Musthafa Zaki Bahar
# #NIM  : 1301190335

# %% [markdown]
# - Buatlah plotting 3D menggunakan (i) surface plot dan (ii) contour plot untuk data 3D.
# - Data yang digunakan pada plotting diambil dari public data set yang tautannya dituliskan pada notebook.
# - Berikan deskripsi singkat terkait dengan hasil plotting.
# - File yang dikumpulkan adalah file jupyter notebook (ipynb) yang digunakan untuk plotting.
# - Waktu pengumpulan tugas adalah 3 Nov 2022; 17.00

# %% [markdown]
# Link Dataset : https://www.kaggle.com/datasets/arshid/iris-flower-dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
df = pd.read_csv("IRIS.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##Surface Plot

# %%
X = df.sepal_length
Y = df.sepal_width
def getZ(X, Y):
    return np.sin(np.sqrt(X ** 2 + Y ** 2))

X, Y = np.meshgrid(X, Y)
Z = getZ(X, Y)

fig = plt.figure()
ax = Axes3D(fig)

surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.set_title('Surface Plot')

plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11876\1398241983.py:10: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Puncak Plot sesuai dengan nilai Z, terjadi pada Sepal Length Yang Mendekati Nilai Tertinggi dan Sepal Widht pada range 2 - 4

# %% [markdown]
# ##Contour Plot

# %%
X = df.sepal_length
Y = df.sepal_width
def func(X, Y):
    return np.sin(X) ** 5 + np.cos(10 + Y * X) * np.cos(X)

X, Y = np.meshgrid(X, Y)
Z = func(X, Y)

fig = plt.figure()
ax = plt.axes()

ax.contour  (X, Y, Z
            , cmap = 'winter'
            );
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

# %% [markdown]
# Puncak Plot nilai Z yang diinterpretasi dengan warna biru->hijau, terjadi pada Sepal Length Yang Mendekati Nilai Tertinggi dan Sepal Widht pada range 2 - 4
